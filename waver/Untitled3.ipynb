# %%
import waver as wv
from astropy import units as u

# %%
wv.waveplotter(RA=162.8042198, DEC=28.00620711, framesize=4.0*u.arcmin, frame='icrs',
               NVSS_radius=.005, SDSS_radius=.0025, CSC_radius=.005)
# Out:
# ...
# Success!
# ...
# Success!
# WARNING: W03: None:13:0: W03: Implicitly generating an ID from a name 'RA:162.8042198,DEC:28.00620711,RASIZE:0.0666666666667,DECSIZE:0.0666666666667,VERB:3,FORMAT:IMAGE/FITS,TIME:2018/03/14_20:29:14' -> 'RA_162.8042198_DEC_28.00620711_RASIZE_0.0666666666667_DECSIZE_0.0666666666667_VERB_3_FORMAT_IMAGE_FITS_TIME_2018_03_14_20_29_14' [astropy.io.votable.xmlutil]
# ...
# No image currently available for Chandra :(
# WARNING: W03: None:8:0: W03: Implicitly generating an ID from a name 'RA:162.8042198,DEC:28.00620711,SR:0.005,VERB:2,TIME:2018/03/14_16:29:59' -> 'RA_162.8042198_DEC_28.00620711_SR_0.005_VERB_2_TIME_2018_03_14_16_29_59' [astropy.io.votable.xmlutil]
# INFO: Auto-setting vmin to -1.455e-03 [aplpy.core]
# INFO: Auto-setting vmax to  4.050e-03 [aplpy.core]
# INFO: Auto-setting vmin to  9.850e+02 [aplpy.core]
# INFO: Auto-setting vmax to  1.780e+03 [aplpy.core]
