# %%
import time
t0 = time.time()
devin_tot = sum(range(3,100000,3)) + sum(range(5,100000,5)) - sum(range(15,100000,15))
t1 = time.time()
bb_tot = 0
for i in xrange(0,100000):
    bb_tot += (i/3)+(i/5)-(i/15)
t2 = time.time()
dev_list = sum([(i/3 + i/5-i/15) for i in range(0,100000)])
t3 = time.time()
devin_time = t1-t0
bb_time = t2-t1
dev_list_time = t3-t2

if devin == bb:
    print "too close to call"
elif devin_time >= bb_time:
    print "chris is faster with a lead of {} seconds".format(devin_time-bb_time)
else:
    print "devin is faster with a lead of {} seconds".format(bb_time-devin_time)
print devin_tot, bb_tot, dev_list
print devin_time, bb_time, dev_list_time
print max(devin_time, bb_time, dev_list_time)/min(devin_time, bb_time, dev_list_time)
# Out:
# devin is faster with a lead of 0.0539999008179 seconds
# 2333316668 2333283332 2333283332
# 0.00200009346008 0.055999994278 0.0520000457764
# 27.9986887591

# %%
import aplpy
from astroquery.sdss import SDSS
from astropy import coordinates as coords
from astropy.io import fits
from astropy.table import Table
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import numpy as np
import pandas as pd

# %%
pos = coords.SkyCoord('11h58m45.4s -00d27m16s', frame='icrs')
obj = SDSS.get_spectra(pos, data_release=14)[0]

# %%
obj.info()
obj.close()
# Out:
# Filename: (No file associated with this HDUList)
# No.    Name         Type      Cards   Dimensions   Format
#   0  PRIMARY     PrimaryHDU     139   ()
#   1  COADD       BinTableHDU     26   3838R x 8C   [E, E, E, J, J, E, E, E]
#   2  SPECOBJ     BinTableHDU    262   1R x 126C   [6A, 4A, 16A, 23A, 16A, 8A, E, E, E, J, E, E, J, B, B, B, B, B, B, J, 22A, 19A, 19A, 22A, 19A, I, 3A, 3A, 1A, J, D, D, D, E, E, 19A, 8A, J, J, J, J, K, K, J, J, J, J, J, J, K, K, K, K, I, J, J, J, J, 5J, D, D, 6A, 21A, E, E, E, J, E, 24A, 10J, J, 10E, E, E, E, E, E, E, J, E, E, E, J, E, 5E, E, 10E, 10E, 10E, 5E, 5E, 5E, 5E, 5E, J, J, E, E, E, E, E, E, 25A, 21A, 10A, E, E, E, E, E, E, E, E, J, E, E, J, 1A, 1A, E, E, J, J, 1A, 5E, 5E]
#   3  SPZLINE     BinTableHDU     48   29R x 19C   [J, J, J, 13A, D, E, E, E, E, E, E, E, E, E, E, J, J, E, E]
#   4  B1-00003513-00003511-00003512  BinTableHDU    144   2042R x 7C   [E, E, E, J, E, E, E]
# ...

# %%
obj[0].header
# Out:
# SIMPLE  =                    T / conforms to FITS standard
# BITPIX  =                    8 / array data type
# NAXIS   =                    0 / number of array dimensions
# EXTEND  =                    T
# TAI     =        4463696955.94 / 1st row - Number of seconds since Nov 17 1858
# RA      =            179.56018 / 1st row - Right ascension of telescope boresigh
# DEC     =           -0.015895  / 1st row - Declination of telescope boresight (d
# EQUINOX =              2000.00 /
# RADECSYS= 'FK5     '           /
# TAIHMS  = '03:22:00.79'        / 1st row - TAI time (HH:MM:SS.SS) (TAI-UT = appr
# TIMESYS = 'tai     '           / TAI, not UTC
# MJD     =                51663 / MJD of observation
# MJDLIST = '51663   '           /
# VERSION = 'v3_13_1branch_1'    / version of IOP
# CAMVER  = 'SPEC2 v4_5'         / Camera code version
# OBSERVER= 'long    '
# TELESCOP= 'SDSS 2.5-M'         / Sloan Digital Sky Survey
# BESTEXP =                 3516 /
# ...
